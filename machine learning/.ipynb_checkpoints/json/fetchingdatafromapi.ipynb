# %%
import pandas as pd    
import requests

# %%
respons=requests.get("https://www.omdbapi.com/?t=Inception&apikey=e620f3b2")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File e:\Anaconda\envs\myenv\lib\socket.py:966, in getaddrinfo(host, port, family, type, proto, flags)
#     965 addrlist = []
# --> 966 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     967     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000014BFADDA310>: Failed to resolve 'www.omdbapi.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File e:\Anaconda\envs\myenv\lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.omdbapi.com', port=443): Max retries exceeded with url: /?t=Inception&apikey=e620f3b2 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014BFADDA310>: Failed to resolve 'www.omdbapi.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 respons=requests.get("https://www.omdbapi.com/?t=Inception&apikey=e620f3b2")
#
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File e:\Anaconda\envs\myenv\lib\site-packages\requests\adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.omdbapi.com', port=443): Max retries exceeded with url: /?t=Inception&apikey=e620f3b2 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000014BFADDA310>: Failed to resolve 'www.omdbapi.com' ([Errno 11001] getaddrinfo failed)"))

# %%
d=respons.json()

print(d)
# Out:
# {'Title': 'Inception', 'Year': '2010', 'Rated': 'PG-13', 'Released': '16 Jul 2010', 'Runtime': '148 min', 'Genre': 'Action, Adventure, Sci-Fi', 'Director': 'Christopher Nolan', 'Writer': 'Christopher Nolan', 'Actors': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page', 'Plot': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.', 'Language': 'English, Japanese, French', 'Country': 'United States, United Kingdom', 'Awards': 'Won 4 Oscars. 159 wins & 220 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '87%'}, {'Source': 'Metacritic', 'Value': '74/100'}], 'Metascore': '74', 'imdbRating': '8.8', 'imdbVotes': '2,705,756', 'imdbID': 'tt1375666', 'Type': 'movie', 'DVD': 'N/A', 'BoxOffice': '$292,587,330', 'Production': 'N/A', 'Website': 'N/A', 'Response': 'True'}

# %%
df = pd.DataFrame(d)
#df.to_csv('movie.csv',index=False)

# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in e:\anaconda\envs\myenv\lib\site-packages (2.3.1)
# Requirement already satisfied: requests in e:\anaconda\envs\myenv\lib\site-packages (2.32.4)
# Requirement already satisfied: numpy>=1.22.4 in e:\anaconda\envs\myenv\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\envs\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\myenv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\myenv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\myenv\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\myenv\lib\site-packages (from requests) (2025.7.14)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head(10)
# Out:
#        Title  Year  Rated     Released  Runtime                      Genre  \
# 0  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 1  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 2  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
#
#             Director             Writer  \
# 0  Christopher Nolan  Christopher Nolan
# 1  Christopher Nolan  Christopher Nolan
# 2  Christopher Nolan  Christopher Nolan
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                                                 Plot  ... Metascore  \
# 0  A thief who steals corporate secrets through t...  ...        74
# 1  A thief who steals corporate secrets through t...  ...        74
# 2  A thief who steals corporate secrets through t...  ...        74
#
#   imdbRating  imdbVotes     imdbID   Type  DVD     BoxOffice Production  \
# 0        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
# 1        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
# 2        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
#
#   Website Response
# 0     N/A     True
# 1     N/A     True
# 2     N/A     True
#
# [3 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       3 non-null      object
#  1   Year        3 non-null      object
#  2   Rated       3 non-null      object
#  3   Released    3 non-null      object
#  4   Runtime     3 non-null      object
#  5   Genre       3 non-null      object
#  6   Director    3 non-null      object
#  7   Writer      3 non-null      object
#  8   Actors      3 non-null      object
#  9   Plot        3 non-null      object
#  10  Language    3 non-null      object
#  11  Country     3 non-null      object
#  12  Awards      3 non-null      object
#  13  Poster      3 non-null      object
#  14  Ratings     3 non-null      object
#  15  Metascore   3 non-null      object
#  16  imdbRating  3 non-null      object
#  17  imdbVotes   3 non-null      object
#  18  imdbID      3 non-null      object
#  19  Type        3 non-null      object
#  20  DVD         3 non-null      object
#  21  BoxOffice   3 non-null      object
#  22  Production  3 non-null      object
#  23  Website     3 non-null      object
#  24  Response    3 non-null      object
# dtypes: object(25)
# memory usage: 728.0+ bytes

# %%
df.to_csv('movie.csv',index=False)
df
# Out:
#        Title  Year  Rated     Released  Runtime                      Genre  \
# 0  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 1  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
# 2  Inception  2010  PG-13  16 Jul 2010  148 min  Action, Adventure, Sci-Fi
#
#             Director             Writer  \
# 0  Christopher Nolan  Christopher Nolan
# 1  Christopher Nolan  Christopher Nolan
# 2  Christopher Nolan  Christopher Nolan
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 2  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                                                 Plot  ... Metascore  \
# 0  A thief who steals corporate secrets through t...  ...        74
# 1  A thief who steals corporate secrets through t...  ...        74
# 2  A thief who steals corporate secrets through t...  ...        74
#
#   imdbRating  imdbVotes     imdbID   Type  DVD     BoxOffice Production  \
# 0        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
# 1        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
# 2        8.8  2,705,756  tt1375666  movie  N/A  $292,587,330        N/A
#
#   Website Response
# 0     N/A     True
# 1     N/A     True
# 2     N/A     True
#
# [3 rows x 25 columns]

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy<1.16,>=1.4.1 (from ydata-profiling)
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in e:\anaconda\envs\myenv\lib\site-packages (from ydata-profiling) (2.3.1)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling)
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting pydantic>=2 (from ydata-profiling)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting PyYAML<6.1,>=5.0.0 (from ydata-profiling)
#   Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Collecting jinja2<3.2,>=2.11.1 (from ydata-profiling)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in e:\anaconda\envs\myenv\lib\site-packages (from ydata-profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.5-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in e:\anaconda\envs\myenv\lib\site-packages (from ydata-profiling) (2.32.4)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.5-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<=0.61,>=0.56.0 (from ydata-profiling)
#   Downloading numba-0.60.0-cp39-cp39-win_amd64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.6.0-cp39-cp39-win_amd64.whl.metadata (9.0 kB)
# Collecting pillow (from imagehash==4.3.1->ydata-profiling)
#   Downloading pillow-11.3.0-cp39-cp39-win_amd64.whl.metadata (9.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=2.11.1->ydata-profiling)
#   Downloading MarkupSafe-3.0.2-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Downloading fonttools-4.59.0-cp39-cp39-win_amd64.whl.metadata (110 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\envs\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Collecting pyparsing>=2.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\envs\myenv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib<=3.10,>=3.5->ydata-profiling)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba<=0.61,>=0.56.0->ydata-profiling)
#   Downloading llvmlite-0.43.0-cp39-cp39-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\envs\myenv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\envs\myenv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.11.1->ydata-profiling)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\envs\myenv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.7.14)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: colorama in e:\anaconda\envs\myenv\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: importlib_metadata>=3.6 in e:\anaconda\envs\myenv\lib\site-packages (from typeguard<5,>=3->ydata-profiling) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in e:\anaconda\envs\myenv\lib\site-packages (from typeguard<5,>=3->ydata-profiling) (4.14.1)
# Collecting attrs>=19.3.0 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=2.4 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: zipp>=3.20 in e:\anaconda\envs\myenv\lib\site-packages (from importlib_metadata>=3.6->typeguard<5,>=3->ydata-profiling) (3.23.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2->ydata-profiling)
#   Downloading pydantic_core-2.33.2-cp39-cp39-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2->ydata-profiling)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in e:\anaconda\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.8 MB 5.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.8 MB 6.0 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/7.8 MB 6.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/7.8 MB 6.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.8 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 6.3 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.60.0-cp39-cp39-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------------------- ---------------- 1.6/2.7 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 8.2 MB/s eta 0:00:00
# Downloading llvmlite-0.43.0-cp39-cp39-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/28.1 MB 1.7 MB/s eta 0:00:17
#    -- ------------------------------------- 1.6/28.1 MB 3.5 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.1/28.1 MB 5.0 MB/s eta 0:00:06
#    ------- -------------------------------- 5.2/28.1 MB 6.1 MB/s eta 0:00:04
#    --------- ------------------------------ 6.8/28.1 MB 6.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.9/28.1 MB 6.2 MB/s eta 0:00:04
#    ------------- -------------------------- 9.4/28.1 MB 6.4 MB/s eta 0:00:03
#    -------------- ------------------------- 10.5/28.1 MB 6.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.1/28.1 MB 6.3 MB/s eta 0:00:03
#    ------------------ --------------------- 12.8/28.1 MB 6.5 MB/s eta 0:00:03
#    -------------------- ------------------- 14.7/28.1 MB 6.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 16.8/28.1 MB 6.6 MB/s eta 0:00:02
#    -------------------------- ------------- 18.9/28.1 MB 6.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 20.2/28.1 MB 6.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 21.0/28.1 MB 6.9 MB/s eta 0:00:02
#    --------------------------------- ------ 23.9/28.1 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 26.0/28.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  28.0/28.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 7.2 MB/s eta 0:00:00
# Downloading phik-0.12.5-cp39-cp39-win_amd64.whl (674 kB)
#    ---------------------------------------- 0.0/674.4 kB ? eta -:--:--
#    ---------------------------------------- 674.4/674.4 kB 8.8 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp39-cp39-win_amd64.whl (162 kB)
# Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.6/46.2 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.9/46.2 MB 7.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/46.2 MB 7.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.6/46.2 MB 7.7 MB/s eta 0:00:06
#    ------- -------------------------------- 8.7/46.2 MB 8.1 MB/s eta 0:00:05
#    -------- ------------------------------- 10.0/46.2 MB 7.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 11.8/46.2 MB 7.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.8/46.2 MB 7.8 MB/s eta 0:00:05
#    ------------ --------------------------- 14.4/46.2 MB 7.5 MB/s eta 0:00:05
#    ------------- -------------------------- 16.0/46.2 MB 7.5 MB/s eta 0:00:05
#    -------------- ------------------------- 17.3/46.2 MB 7.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.6/46.2 MB 7.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 20.4/46.2 MB 7.4 MB/s eta 0:00:04
#    ------------------- -------------------- 22.3/46.2 MB 7.4 MB/s eta 0:00:04
#    -------------------- ------------------- 23.9/46.2 MB 7.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.7/46.2 MB 7.6 MB/s eta 0:00:03
#    ----------------------- ---------------- 27.5/46.2 MB 7.6 MB/s eta 0:00:03
#    ------------------------- -------------- 29.1/46.2 MB 7.7 MB/s eta 0:00:03
#    -------------------------- ------------- 30.7/46.2 MB 7.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 32.8/46.2 MB 7.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.6/46.2 MB 7.8 MB/s eta 0:00:02
#    ------------------------------- -------- 36.7/46.2 MB 7.9 MB/s eta 0:00:02
#    -------------------------------- ------- 38.0/46.2 MB 7.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.8/46.2 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------ --- 42.2/46.2 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.6/46.2 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 8.0 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.5-cp39-cp39-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.7 MB 114.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.7 MB 14.8 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.7 MB 14.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.9 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading fonttools-4.59.0-cp39-cp39-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 11.6 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Downloading MarkupSafe-3.0.2-cp39-cp39-win_amd64.whl (15 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------------- - 1.6/1.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 5.9 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pillow-11.3.0-cp39-cp39-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.0 MB 11.2 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/7.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 10.2 MB/s eta 0:00:00
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp39-cp39-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 9.9 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl (300 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading pywavelets-1.6.0-cp39-cp39-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.8/4.3 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.7/4.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 8.5 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27172 sha256=ca6ecf95ed64e30c8ef390ca1063febf29da1eb5da80b6d9f12a40b2bf9fc228
#   Stored in directory: c:\users\om420\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, typing-inspection, tqdm, scipy, PyYAML, PyWavelets, pyparsing, pydantic-core, pillow, patsy, networkx, multimethod, MarkupSafe, llvmlite, kiwisolver, joblib, importlib-resources, fonttools, dacite, cycler, contourpy, attrs, annotated-types, typeguard, pydantic, numba, matplotlib, jinja2, imagehash, wordcloud, visions, statsmodels, seaborn, phik, ydata-profiling
#
#    --- ------------------------------------  3/36 [tqdm]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ---- -----------------------------------  4/36 [scipy]
#    ------ ---------------------------------  6/36 [PyWavelets]
#    ------- --------------------------------  7/36 [pyparsing]
#    ---------- -----------------------------  9/36 [pillow]
#    ---------- -----------------------------  9/36 [pillow]
#    ---------- -----------------------------  9/36 [pillow]
#    ----------- ---------------------------- 10/36 [patsy]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    ------------ --------------------------- 11/36 [networkx]
#    --------------- ------------------------ 14/36 [llvmlite]
#    --------------- ------------------------ 14/36 [llvmlite]
#    --------------- ------------------------ 14/36 [llvmlite]
#    --------------- ------------------------ 14/36 [llvmlite]
#    --------------- ------------------------ 14/36 [llvmlite]
#    --------------- ------------------------ 14/36 [llvmlite]
#    ----------------- ---------------------- 16/36 [joblib]
#    ----------------- ---------------------- 16/36 [joblib]
#    ------------------ --------------------- 17/36 [importlib-resources]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#    -------------------- ------------------- 18/36 [fonttools]
#
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'htmlmin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'htmlmin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'e:\\Anaconda\\envs\\myenv\\Scripts\\pyftsubset.exe'
# Consider using the `--user` option or check the permissions.
